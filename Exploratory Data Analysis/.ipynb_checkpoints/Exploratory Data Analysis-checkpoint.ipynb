# %% [markdown]
# ### Loading the required libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams['agg.path.chunksize'] = 10000
import re
from collections import Counter  
from scipy.stats import norm

# %%
df_anime = pd.read_csv('E:\\Personal Projects\\Anime recommendation\\Anime-Recommendation\\Input data\\Anime dataset\\anime.csv')
df_rating = pd.read_csv('E:\\Personal Projects\\Anime recommendation\\Anime-Recommendation\\Input data\\Anime dataset\\rating.csv')

# %%
df_anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
df_anime.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %% [markdown]
# - We have around 62 null values in genre . Genre has multiple tags associated with it for a single record such as Drama , romance , thriller , scifi etc. So these values can be imputed by posing this problem as a multilabel classification.
# <br>
# - We have around 25 null values in type for which the corresponding episodes and ratings are also unknown.<br>
# - We have around 230 null values in rating. Some of them are human errors such as Steins;Gate 0, One Punch Man 2.  These values can be used as a test set but we cant measure the effectivenes as we dont know their original ratings.<br>
#
# Since we are focusing solely on the recommendation and the number of null values are small in number we will drop these values.

# %%
df_anime.dropna(inplace = True)

# %%
df_rating
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
df_rating.isnull().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %% [markdown]
# We have no null values in the ratings dataset.

# %% [markdown]
# ### Information about the data:

# %% [markdown]
# Description downloaded from Kaggle : https://www.kaggle.com/CooperUnion/anime-recommendations-database
#
#
# **Anime.csv**
#
# - anime_id - myanimelist.net's unique id identifying an anime.
# - name - full name of anime.
# - genre - comma separated list of genres for this anime.
# - type - movie, TV, OVA, etc.
# - episodes - how many episodes in this show. (1 if movie).
# - rating - average rating out of 10 for this anime.
# - members - number of community members that are in this anime's "group".
#
# **Rating.csv**
#
# - user_id - non identifiable randomly generated user id.
# - anime_id - the anime that this user has rated.
# - rating - rating out of 10 this user has assigned (-1 if the user watched it but didn't assign a rating).

# %% [markdown]
# ## Data Cleaning and Exploratory data analysis:

# %% [markdown]
# #### Analysis on name - (anime dataframe)

# %%
#removing the  punctuations and junk characters from the name
# Numbers are not removed as some animes with an prequel or an sequel are considered as an seperate anime
# and some anime have numbers associated with their name.
df_anime['name'] =  [re.sub('[^A-Za-z0-9\s]+' , "" , x) for x in df_anime['name']]

# %%
#quot HTML tag is also present in some of the names
df_anime['name'] =  [re.sub('quot' , "" , x) for x in df_anime['name']]

# %%
#Some anime have only numbers in the name
for x in range(len(df_anime)):
    if re.search('^\d+$' , df_anime.iloc[x]['name']):
        print(df_anime.iloc[x]['name'])
# Out:
# 0091
# 1989
# 100
# 663114
# 2010
# 0008
# 0
# 001

# %% [markdown]
# These animes have corrupted name in our dataset but they have an valid anime id. So these are not junk values and shouldnt be removed as they might provide valuable insights.

# %%
# No duplicates in the anime id but there are some anime with almost same name ,genre , type and number of episodes
df_anime[df_anime['anime_id'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [anime_id, name, genre, type, episodes, rating, members]
# Index: []

# %%
#Grouping the anime by genre , type and episodes to see if any duplicates are present.

# %%
temp_df = df_anime[df_anime['genre'].duplicated()]
temp_df = temp_df[temp_df['type'].duplicated()]
temp_df = temp_df[temp_df['episodes'].duplicated()]
temp_df = temp_df.sort_values('name' ,ascending = False )
temp_df.head(5)
# Out:
#       anime_id                                    name  \
# 341       4918                       xxxHOLiC Shunmuki
# 484        793  xxxHOLiC Movie Manatsu no Yoru no Yume
# 410        861                                xxxHOLiC
# 9849      8229             onchan Yume Power Daibouken
# 7348     32346                               makemagic
#
#                                                   genre     type episodes  \
# 341   Comedy, Drama, Mystery, Psychological, Superna...      OVA        2
# 484   Comedy, Drama, Mystery, Psychological, Superna...    Movie        1
# 410   Comedy, Drama, Mystery, Psychological, Superna...       TV       24
# 9849                                            Fantasy  Special        1
# 7348                                     Fantasy, Music    Music        1
#
#       rating  members
# 341     8.17    40401
# 484     8.04    41547
# 410     8.11   150872
# 9849    5.40       98
# 7348    5.52      178

# %% [markdown]
# - We can see that from the first 3 examples a single anime **xxxHOLiC** can have OVA , movie and TV types and each are considered as a seperate records and  the count of the members varies accordingly.
# <br>
# <br>
# - So we can conclude that might be no duplicate animes but we can have different types of the same anime. Name is not an important feature and it can be discarded for further analysis.

# %%
df_anime.drop('name' , axis = 1 , inplace = True)

# %% [markdown]
# #### Analysis on genre - (anime dataframe)

# %%
genre = []
for val in df_anime['genre']:
    split_val = (val.split(','))
    for genre_val in split_val:
        genre_val = genre_val.strip() #Some of them had leading white spaces
        genre.append(genre_val)

# %%
genre_count = (Counter(genre))
genre_count = {k: v for k, v in sorted(genre_count.items(), key=lambda item: item[1] , reverse = True)}
top_genre_count = list(genre_count)[0:5] # selecting the top 5 frequently occuring genre to check the ratings

# %% [markdown]
# - Comedy: 4575
# - Action: 2768
# - Adventure: 2316
# - Fantasy: 2242
# - Sci-Fi: 2036

# %%
comedy_rating = []
action_rating = []
adventure_rating = []
fantasy_rating = []
scifi_rating = []

for df_val in range(len(df_anime)):
    if 'Comedy' in  df_anime.iloc[df_val]['genre']:
        comedy_rating.append(df_anime.iloc[df_val]['rating'])
        
    if 'Action' in  df_anime.iloc[df_val]['genre']:
        action_rating.append(df_anime.iloc[df_val]['rating'])
        
    if 'Adventure' in  df_anime.iloc[df_val]['genre']:
        adventure_rating.append(df_anime.iloc[df_val]['rating'])
        
    if 'Fantasy' in  df_anime.iloc[df_val]['genre']:
        fantasy_rating.append(df_anime.iloc[df_val]['rating'])
        
    if 'Sci-Fi' in  df_anime.iloc[df_val]['genre']:
        scifi_rating.append(df_anime.iloc[df_val]['rating'])

# %%
temp_genre_type = pd.DataFrame({"Genre":['Comedy' , 'Action' , "Fantasy" , "Adventure" , "Sci-fi"] , 'Median_Rating':
                               [np.median(comedy_rating),np.median(action_rating),
                               np.median(fantasy_rating),np.median(adventure_rating),
                               np.median(scifi_rating)]})

print("Median rating of the genre Comedy is"  , np.median(comedy_rating))
print("Median rating of the genre Action is"  , np.median(action_rating))
print("Median rating of the genre Adventure is"  , np.median(adventure_rating))
print("Median rating of the genre fantasy is"  , np.median(fantasy_rating))
print("Median rating of the genre scifi is"  , np.median(scifi_rating))
# Out:
# Median rating of the genre Comedy is 6.74
# Median rating of the genre Action is 6.88
# Median rating of the genre Adventure is 6.78
# Median rating of the genre fantasy is 6.725
# Median rating of the genre scifi is 6.76

# %%
sns.barplot(temp_genre_type['Genre'] , temp_genre_type['Median_Rating'])
# Out:
# e:\personal projects\projects\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Genre', ylabel='Median_Rating'>

# %% [markdown]
# - From this analysis we can see that even though the genre comedy is very high in number the median rating is only 6.74 (considered in terms of anime rating, not user rating)
# <br>
# - This implies there may be a possibility that when an anime is only a combination of mutiple genres the rating might be higher.

# %%
single_genre = []
multi_genre = []

#Can be added as a New Binary Feature

for val in range(len(df_anime)):
    if ',' not in df_anime.iloc[val]['genre']:
        single_genre.append(val)
print('Single genre median rating :' , df_anime.iloc[single_genre]['rating'].median())

for val in range(len(df_anime)):
    if ','  in df_anime.iloc[val]['genre']:
        multi_genre.append(val)
print('Multi genre median rating :' , df_anime.iloc[multi_genre]['rating'].median())

temp_genre = pd.DataFrame({'Genre':['Single Genre' , 'Multi Genre'] , 'Median_Rating':[df_anime.iloc[single_genre]['rating'].median(),
                                                                                     df_anime.iloc[multi_genre]['rating'].median()]})
# Out:
# Single genre median rating : 6.02
# Multi genre median rating : 6.73

# %%
sns.barplot(temp_genre['Genre'] , temp_genre['Median_Rating'])
# Out:
# e:\personal projects\projects\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Genre', ylabel='Median_Rating'>

# %% [markdown]
# - This analysis proves that Multi genre anime is better than the single genre anime.<br><br>
# **Note: Experiment done on the overall anime rating not on the user provided rating.**

# %%
# TBD : Analyze the genre rating by users

# %% [markdown]
# #### Analysis on type - (anime dataframe)

# %%
df_anime['type'].value_counts()
# Out:
# TV         3668
# OVA        3284
# Movie      2259
# Special    1670
# ONA         648
# Music       488
# Name: type, dtype: int64

# %% [markdown]
# In our dataset most of the users fall into the TV , OVA , Movie and Special types whereas ONA and Music has the least distribution.

# %%
temp_type = df_anime.groupby('type')
temp_type = temp_type.median()
sns.barplot( temp_type.index , temp_type.rating)
# Out:
# e:\personal projects\projects\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='rating'>

# %% [markdown]
# - From the underlying graph it shows that type of the anime doesnt affect the overall rating of the anime that much.

# %% [markdown]
# #### Analysis on members - (anime dataframe)

# %%
sns.lineplot( df_anime['rating'] , df_anime['members'])
# Out:
# e:\personal projects\projects\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='rating', ylabel='members'>

# %% [markdown]
# - One Interesting Observation is that the members of the anime group exponentially increased when the rating is above 8.
# - So if the anime is exceptionally good there might be higher chances that users join that group to keep track of the further releases or to dicuss their thoughts on that anime in general.

# %% [markdown]
# #### Analysis on ratings - (ratings dataframe)

# %%
sns.distplot()

# %%
temp_df = df_rating[df_rating['rating']!=-1]
sns.FacetGrid(temp_df).map(sns.distplot , 'rating').add_legend()
plt.title(label = 'PDF of Ratings')
# Out:
# e:\personal projects\projects\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'PDF of Ratings')

# %% [markdown]
# - We can see that the PDF of the rating follows a n-modal distribution. i.e The modes of the rating distribution are predominant in the area 7,8 and 9. [Global maxima : 8 , local maxima : 7,9]

# %%
count, bins = np.histogram(temp_df['rating'], bins=10, density = True)
pdf = count/(sum(count))
cdf = np.cumsum(pdf)
plt.plot(bins[1:],pdf, label = 'pdf of ratings')
plt.plot(bins[1:], cdf, label = 'cdf of ratings')
plt.title("CDF and PDF analysis of ratings")
plt.xlabel('Ratings')
plt.ylabel("probability of ratings")
plt.legend()

# %% [markdown]
# - 60% of the data have their rating less than or equal to 8. This implies that majority of the users are very critical about how they rate the anime shows.
# - 40% of the data have a rating >8 which shows that there might be some anime shows which might be very good which all users may agree upon or that there might be some set of users who tend to give higher rating or tend to be liberal.

# %% [markdown]
# ### Splitting the data into train- test:

# %% [markdown]
# Since we dont have any timestamps  associated with our data we split the data randomly.

# %%
#Creating a new  dataset by using rating and anime.
data = pd.merge(df_rating , df_anime , on = 'anime_id',suffixes=('_user', '_anime'))
data_unknown = data[data['rating_user'] == -1]
data = data[data['rating_user']!= -1]
data = data.iloc[:,0:3] # Selecting only the first 3 columns as they contribute more to the model building perspective
data['index'] = data.index

# %%
data_train = data.sample(frac = 0.8 , random_state=10)
data_test = data[~data['index'].isin(data_train['index'])]
